# %% [markdown]
# # Semana 5: Mis Primeros Gráficos con Python
#
# ## Bloque 1: Prerrequisitos de Programación con Python
#
# ---
#
# **Lo que aprenderemos hoy:**
# - Crear gráficos de barras simples
# - Hacer gráficos de líneas básicos
# - Entender para qué sirve cada tipo de gráfico
# - Usar colores y títulos en nuestros gráficos
#
# **¿Por qué es importante?**
# Los gráficos nos ayudan a entender mejor los números y datos del fútbol.
#
# ---

# %% [markdown]
# ## 1. ¿Qué son los Gráficos?
#
# Los **gráficos** son dibujos que nos ayudan a entender números más fácilmente.
#
# ### Un Ejemplo Simple
#
# Imagina que quieres saber qué equipo marcó más goles:
#
# - **Solo números**: Barcelona: 25, Madrid: 20, Valencia: 15
# - **Con gráfico**: Verías inmediatamente que Barcelona tiene la barra más alta
#
# ### Los Gráficos que Aprenderemos
#
# 1. **Gráficos de barras**: Para comparar equipos (¿quién marcó más goles?)
# 2. **Gráficos de líneas**: Para ver cómo cambian las cosas en el tiempo
#
# ¡Es más fácil de lo que piensas!

# %% [markdown]
# ## 2. Preparando Python para Hacer Gráficos
#
# Antes de dibujar, necesitamos decirle a Python qué herramientas usar.
#
# Vamos a usar **seaborn** porque hace gráficos más bonitos automáticamente.

# %%
# Importar las herramientas para hacer gráficos bonitos
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar seaborn para gráficos más atractivos
sns.set_theme()

# Verificar que todo funcione
print("✅ ¡Listo para hacer gráficos bonitos!")
print("🎨 Seaborn hará que nuestros gráficos se vean increíbles")
# Out:
# ✅ ¡Listo para hacer gráficos bonitos!
# 🎨 Seaborn hará que nuestros gráficos se vean increíbles

# %% [markdown]
# ## 3. Mi Primer Gráfico: Barras
#
# Los **gráficos de barras** son perfectos cuando queremos comparar cosas.
#
# **¿Cuándo los usamos?**
# - Para ver qué equipo marcó más goles
# - Para comparar cuántos partidos ganó cada equipo
# - Para saber qué jugador es más alto
#
# ¡Vamos a hacer nuestro primer gráfico!

# %%
# Datos simples: goles de algunos equipos
equipos = ['Barcelona', 'Madrid', 'Valencia']
goles = [25, 20, 15]

# Crear el gráfico de barras con seaborn (¡más fácil!)
sns.barplot(x=equipos, y=goles)

# Agregar título
plt.title('Goles por Equipo')

# Mostrar el gráfico
plt.show()

print("🎉 ¡Hiciste tu primer gráfico!")
print("📊 ¡Mira qué bonito se ve con seaborn!")
print("🌈 Los colores son automáticos y profesionales")
# Out:
# 🎉 ¡Hiciste tu primer gráfico!
# 📊 ¡Mira qué bonito se ve con seaborn!
# 🌈 Los colores son automáticos y profesionales

# %% [markdown]
# ### ¿Por qué usar Seaborn?
#
# Seaborn es genial porque:
# - **Colores automáticos**: Ya no tienes que elegir colores
# - **Más bonito**: Los gráficos se ven profesionales sin esfuerzo
# - **Más fácil**: Menos código para el mismo resultado
# - **Estilo moderno**: Como los gráficos que ves en deportes profesionales

# %%
# Los mismos datos de antes
equipos = ['Barcelona', 'Madrid', 'Valencia']
goles = [25, 20, 15]

# Crear gráfico con seaborn y una paleta de colores bonita
sns.barplot(x=equipos, y=goles, palette='viridis')

# Agregar título y etiquetas
plt.title('Goles por Equipo', fontsize=16)
plt.xlabel('Equipos')
plt.ylabel('Número de Goles')

# Mostrar el gráfico
plt.show()

print("🌈 ¡Seaborn eligió colores increíbles automáticamente!")
print("✨ La paleta 'viridis' es muy popular en ciencia de datos")
print("🎯 ¡Con una línea de código obtuvimos un gráfico profesional!")
# Out:
# 📈 Promedio de goles: 59.7
# 🏆 Equipo con más goles: Barcelona (75 goles)
# 💡 Con seaborn, obtuvimos colores atractivos automáticamente

# %% [markdown]
# ## 4. Gráficos de Líneas: Viendo Cambios en el Tiempo
#
# Los **gráficos de líneas** son perfectos para ver cómo cambian las cosas.
#
# **¿Cuándo los usamos?**
# - Para ver si un equipo está mejorando mes a mes
# - Para seguir cuántos goles marca un jugador cada partido
#
# ¡Vamos a hacer uno!

# %%
# Datos simples: goles de Barcelona en cada mes
meses = ['Enero', 'Febrero', 'Marzo', 'Abril']
goles_barcelona = [5, 8, 6, 10]

# Crear el gráfico de líneas con seaborn
sns.lineplot(x=meses, y=goles_barcelona, marker='o', linewidth=3, markersize=10)

# Agregar título y etiquetas
plt.title('Goles de Barcelona por Mes')
plt.xlabel('Mes')
plt.ylabel('Goles')

# Mostrar el gráfico
plt.show()

print("📈 ¡Mira qué línea tan bonita hizo seaborn!")
print("🔵 Los puntos y la línea se ven súper profesionales")
print("✨ Seaborn hace que todo se vea mejor automáticamente")
# Out:
# 📊 ANÁLISIS DE TENDENCIAS:
# 🔵 Barcelona - Puntos finales: 43
# 🟡 Real Madrid - Puntos finales: 41
# 📈 Diferencia final: 2 puntos
# 💡 Seaborn simplifica mucho la creación de gráficos multi-línea

# %% [markdown]
# ## 5. ¡Tu Turno! Ejercicio Práctico
#
# Ahora vamos a hacer un gráfico con datos de tu equipo favorito.

# %%
# Ejercicio: Cambia estos datos por los de tu equipo favorito
mi_equipo = "Mi Equipo Favorito"
partidos = ['Partido 1', 'Partido 2', 'Partido 3', 'Partido 4']
goles_por_partido = [2, 1, 3, 0]

# Hacer el gráfico de líneas con seaborn
sns.lineplot(x=partidos, y=goles_por_partido, marker='o', linewidth=3, markersize=8, color='green')

# Personalizar
plt.title(f'Goles de {mi_equipo}', fontsize=14)
plt.xlabel('Partidos')
plt.ylabel('Goles')

# Seaborn ya tiene una grilla bonita automáticamente
plt.show()

print(f"⚽ ¡Excelente! Hiciste un gráfico de {mi_equipo}")
print("💡 Intenta cambiar los números y el nombre del equipo")
print("🎨 ¡Seaborn hace que todo se vea increíble sin esfuerzo!")
# Out:
# 📊 ESTADÍSTICAS MENSUALES:
# ⚽ Promedio goles a favor: 11.6
# 🥅 Promedio goles en contra: 5.4
# 🏆 Promedio victorias: 3.6
# 📈 Diferencia promedio de goles: 6.2

# %% [markdown]
# ## 6. ¡Felicitaciones! 🎉
#
# ### Lo que Aprendiste Hoy
#
# ✅ **Seaborn**: La herramienta que hace gráficos bonitos automáticamente
# ✅ **Gráficos de barras**: Para comparar equipos con `sns.barplot()`
# ✅ **Gráficos de líneas**: Para ver cambios con `sns.lineplot()`
# ✅ **Paletas de colores**: Colores profesionales sin esfuerzo
# ✅ **Tu primer gráfico**: ¡Ya sabes hacer visualizaciones increíbles!
#
# ### ¿Por qué Seaborn es Genial?
#
# - 🎨 **Colores automáticos**: No tienes que elegir
# - ✨ **Estilo profesional**: Se ve como gráficos de TV deportiva
# - 🚀 **Súper fácil**: Menos código, mejores resultados
# - 📊 **Moderno**: Lo que usan los analistas profesionales
#
# ### ¿Qué Sigue?
#
# Ahora puedes:
# - Probar diferentes paletas: 'viridis', 'plasma', 'Set2'
# - Cambiar los datos en los ejercicios
# - Hacer gráficos de tus equipos favoritos
# - ¡Impresionar a todos con gráficos súper bonitos!
#
# ### Comandos para Recordar
#
# - `sns.barplot()` → Gráfico de barras bonito
# - `sns.lineplot()` → Gráfico de líneas profesional
# - `palette='viridis'` → Colores automáticos geniales
# - `plt.title()` → Agregar título
# - `plt.show()` → Mostrar el gráfico
#
# **¡Ya eres capaz de hacer gráficos profesionales con Python y Seaborn!** 🌟
#
# ---
#
# *Seaborn es la herramienta favorita de los científicos de datos porque hace que todo se vea increíble sin esfuerzo.*
